# %%
maxTicketsAvalibale = 5
participants = []
# Input number of elemetns
print("Enter 5 names in the list : ")
# iterating till the range
for i in range(0, 5):
   print("Enter the name-{}: ".format(i+1))
   names = str(input())
   participants.append(names) # adding the element
print("The entered list is: \n",participants)
# For generating a random number who will be our winner 
import random
print("the winner is")
n = random.randint(0,maxTicketsAvalibale-1)
participants[n]
# Out:
# Enter 5 names in the list :
# Enter the name-1:
# pranjal
# Enter the name-2:
# ravi
# Enter the name-3:
# pallavi
# Enter the name-4:
# tanya
# Enter the name-5:
# vijay
# The entered list is:
#  ['pranjal', 'ravi', 'pallavi', 'tanya', 'vijay']
# the winner is
# 'tanya'
